# %%
import pandas as pd 
import numpy as np
import requests
import logging
import os
import traceback 
import sys
from dotenv import load_dotenv
import psycopg2 
from sqlalchemy import create_engine
load_dotenv()
# Out:
# True

# %%
BASE_DIR = os.getcwd() ## This is used because of coding in jupyter notebook (if in python_file, it changes to "BASE_DIR = os.path.dirname(os.path.abspath(__file__)))
LOG_PATH = os.path.join(BASE_DIR, ".env")

LOG_PATH = os.path.join(BASE_DIR, "etl.log")
logging.basicConfig(
    filename=LOG_PATH,
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(message)s"
)

logging.info("ETL job started")
logging.info("Extracting data from API...")
logging.warning("API took longer than expected")
logging.error("Failed to load into database")
logging.info("ETL job finished")

# %% [markdown]
# READ CONFIGURATION FROM .env Environment for Retrieval

# %%
url="https://api.rentcast.io/v1/listings/sale?limit=150"
password= os.getenv("DB_PASSWORD")
api_key=os.getenv("API_KEY")
port=os.getenv("PORT")
host=os.getenv("DB_HOST")
user_name=os.getenv("USER")
db=os.getenv("DATABASE")
db_name=os.getenv("DB_NAME")

# %%
headers = {
    "Accept": "application/json",
    "X-Api-Key": api_key   # where api_key = os.getenv("API_KEY")
}

# %% [markdown]
# GET END POINT FROM YOUR API FOR DATA INGESTION

# %%
def extract_data(url):
    '''this function gets a response from a url and returns a dataframe'''
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        df = pd.json_normalize(data)
        return df
    else:
        raise Exception(f"Error fetching data: {response.status_code}- {response.text}")

# %%
df=extract_data(url)
df.head()
# Out:
#                                               id  \
# 0         12763-Battista-Ln,-Henderson,-NV-89044
# 1  1014-Lone-Pine-River-Ave,-Henderson,-NV-89002
# 2   6955-Elysian-Valley-Ave,-Las-Vegas,-NV-89113
# 3   1105-Aubrey-Springs-Ave,-Henderson,-NV-89014
# 4            2486-Sabado-St,-Las-Vegas,-NV-89121
#
#                                 formattedAddress              addressLine1  \
# 0         12763 Battista Ln, Henderson, NV 89044         12763 Battista Ln
# 1  1014 Lone Pine River Ave, Henderson, NV 89002  1014 Lone Pine River Ave
# 2   6955 Elysian Valley Ave, Las Vegas, NV 89113   6955 Elysian Valley Ave
# 3   1105 Aubrey Springs Ave, Henderson, NV 89014   1105 Aubrey Springs Ave
# 4            2486 Sabado St, Las Vegas, NV 89121            2486 Sabado St
#
#   addressLine2       city state stateFips zipCode county countyFips  ...  \
# 0         None  Henderson    NV        32   89044  Clark        003  ...
# 1         None  Henderson    NV        32   89002  Clark        003  ...
# 2         None  Las Vegas    NV        32   89113  Clark        003  ...
# 3         None  Henderson    NV        32   89014  Clark        003  ...
# 4         None  Las Vegas    NV        32   89121  Clark        003  ...
#
#    history.2025-07-10.listingType  history.2025-07-10.listedDate  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   history.2025-07-10.removedDate  history.2025-07-10.daysOnMarket  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
#    history.2025-05-15.event  history.2025-05-15.price  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    history.2025-05-15.listingType  history.2025-05-15.listedDate  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   history.2025-05-15.removedDate  history.2025-05-15.daysOnMarket
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
# [5 rows x 394 columns]

# %%
df.shape
# Out:
# (150, 394)

# %%
df.columns
# Out:
# Index(['id', 'formattedAddress', 'addressLine1', 'addressLine2', 'city',
#        'state', 'stateFips', 'zipCode', 'county', 'countyFips',
#        ...
#        'history.2025-07-10.listingType', 'history.2025-07-10.listedDate',
#        'history.2025-07-10.removedDate', 'history.2025-07-10.daysOnMarket',
#        'history.2025-05-15.event', 'history.2025-05-15.price',
#        'history.2025-05-15.listingType', 'history.2025-05-15.listedDate',
#        'history.2025-05-15.removedDate', 'history.2025-05-15.daysOnMarket'],
#       dtype='object', length=394)

# %%
engine = create_engine(f'postgresql+psycopg2://{user_name}:{password}@{host}:{port}/{db_name}')

# %%
try:
    conn = psycopg2.connect(
        host=host,
        database=db_name,
        user=user_name,
        password=password,
        port=port
    )
    print("Connection successful")
except Exception as e:
    print("Connection was unsuccessful:", e)
# Out:
# Connection successful

# %%
cur=conn.cursor()

# %%
df.to_sql('raw_listings', con=engine, if_exists='replace', index=False,method="multi")
# Out:
# 150

# %%
conn.commit()

# %%
Total_list =list(df.columns)

# %%
Total_list
# Out:
# ['id',
#  'formattedAddress',
#  'addressLine1',
#  'addressLine2',
#  'city',
#  'state',
#  'stateFips',
#  'zipCode',
#  'county',
#  'countyFips',
#  'latitude',
#  'longitude',
#  'propertyType',
#  'bedrooms',
#  'bathrooms',
#  'squareFootage',
#  'lotSize',
#  'yearBuilt',
#  'status',
#  'price',
#  'listingType',
#  'listedDate',
#  'removedDate',
#  'createdDate',
#  'lastSeenDate',
#  'daysOnMarket',
#  'mlsName',
#  'mlsNumber',
#  'hoa.fee',
#  'listingAgent.name',
#  'listingAgent.phone',
#  'listingAgent.email',
#  'listingOffice.name',
#  'listingOffice.phone',
#  'listingOffice.email',
#  'history.2025-07-08.event',
#  'history.2025-07-08.price',
#  'history.2025-07-08.listingType',
#  'history.2025-07-08.listedDate',
#  'history.2025-07-08.removedDate',
#  'history.2025-07-08.daysOnMarket',
#  'listingOffice.website',
#  'history.2025-04-18.event',
#  'history.2025-04-18.price',
#  'history.2025-04-18.listingType',
#  'history.2025-04-18.listedDate',
#  'history.2025-04-18.removedDate',
#  'history.2025-04-18.daysOnMarket',
#  'listingAgent.website',
#  'history.2025-05-16.event',
#  'history.2025-05-16.price',
#  'history.2025-05-16.listingType',
#  'history.2025-05-16.listedDate',
#  'history.2025-05-16.removedDate',
#  'history.2025-05-16.daysOnMarket',
#  'history.2025-01-17.event',
#  'history.2025-01-17.price',
#  'history.2025-01-17.listingType',
#  'history.2025-01-17.listedDate',
#  'history.2025-01-17.removedDate',
#  'history.2025-01-17.daysOnMarket',
#  'history.2024-06-21.event',
#  'history.2024-06-21.price',
#  'history.2024-06-21.listingType',
#  'history.2024-06-21.listedDate',
#  'history.2024-06-21.removedDate',
#  'history.2024-06-21.daysOnMarket',
#  'history.2024-09-24.event',
#  'history.2024-09-24.price',
#  'history.2024-09-24.listingType',
#  'history.2024-09-24.listedDate',
#  'history.2024-09-24.removedDate',
#  'history.2024-09-24.daysOnMarket',
#  'history.2025-04-08.event',
#  'history.2025-04-08.price',
#  'history.2025-04-08.listingType',
#  'history.2025-04-08.listedDate',
#  'history.2025-04-08.removedDate',
#  'history.2025-04-08.daysOnMarket',
#  'history.2025-06-02.event',
#  'history.2025-06-02.price',
#  'history.2025-06-02.listingType',
#  'history.2025-06-02.listedDate',
#  'history.2025-06-02.removedDate',
#  'history.2025-06-02.daysOnMarket',
#  'builder.name',
#  'builder.development',
#  'builder.phone',
#  'history.2025-05-20.event',
#  'history.2025-05-20.price',
#  'history.2025-05-20.listingType',
#  'history.2025-05-20.listedDate',
#  'history.2025-05-20.removedDate',
#  'history.2025-05-20.daysOnMarket',
#  'history.2025-05-07.event',
#  'history.2025-05-07.price',
#  'history.2025-05-07.listingType',
#  'history.2025-05-07.listedDate',
#  'history.2025-05-07.removedDate',
#  'history.2025-05-07.daysOnMarket',
#  'history.2024-12-05.event',
#  'history.2024-12-05.price',
#  'history.2024-12-05.listingType',
#  'history.2024-12-05.listedDate',
#  'history.2024-12-05.removedDate',
#  'history.2024-12-05.daysOnMarket',
#  'history.2025-01-11.event',
#  'history.2025-01-11.price',
#  'history.2025-01-11.listingType',
#  'history.2025-01-11.listedDate',
#  'history.2025-01-11.removedDate',
#  'history.2025-01-11.daysOnMarket',
#  'history.2024-09-17.event',
#  'history.2024-09-17.price',
#  'history.2024-09-17.listingType',
#  'history.2024-09-17.listedDate',
#  'history.2024-09-17.removedDate',
#  'history.2024-09-17.daysOnMarket',
#  'history.2025-04-03.event',
#  'history.2025-04-03.price',
#  'history.2025-04-03.listingType',
#  'history.2025-04-03.listedDate',
#  'history.2025-04-03.removedDate',
#  'history.2025-04-03.daysOnMarket',
#  'history.2025-06-14.event',
#  'history.2025-06-14.price',
#  'history.2025-06-14.listingType',
#  'history.2025-06-14.listedDate',
#  'history.2025-06-14.removedDate',
#  'history.2025-06-14.daysOnMarket',
#  'history.2025-05-06.event',
#  'history.2025-05-06.price',
#  'history.2025-05-06.listingType',
#  'history.2025-05-06.listedDate',
#  'history.2025-05-06.removedDate',
#  'history.2025-05-06.daysOnMarket',
#  'history.2025-04-16.event',
#  'history.2025-04-16.price',
#  'history.2025-04-16.listingType',
#  'history.2025-04-16.listedDate',
#  'history.2025-04-16.removedDate',
#  'history.2025-04-16.daysOnMarket',
#  'history.2024-08-31.event',
#  'history.2024-08-31.price',
#  'history.2024-08-31.listingType',
#  'history.2024-08-31.listedDate',
#  'history.2024-08-31.removedDate',
#  'history.2024-08-31.daysOnMarket',
#  'history.2024-09-13.event',
#  'history.2024-09-13.price',
#  'history.2024-09-13.listingType',
#  'history.2024-09-13.listedDate',
#  'history.2024-09-13.removedDate',
#  'history.2024-09-13.daysOnMarket',
#  'history.2025-02-05.event',
#  'history.2025-02-05.price',
#  'history.2025-02-05.listingType',
#  'history.2025-02-05.listedDate',
#  'history.2025-02-05.removedDate',
#  'history.2025-02-05.daysOnMarket',
#  'history.2025-03-20.event',
#  'history.2025-03-20.price',
#  'history.2025-03-20.listingType',
#  'history.2025-03-20.listedDate',
#  'history.2025-03-20.removedDate',
#  'history.2025-03-20.daysOnMarket',
#  'history.2025-02-08.event',
#  'history.2025-02-08.price',
#  'history.2025-02-08.listingType',
#  'history.2025-02-08.listedDate',
#  'history.2025-02-08.removedDate',
#  'history.2025-02-08.daysOnMarket',
#  'history.2025-03-26.event',
#  'history.2025-03-26.price',
#  'history.2025-03-26.listingType',
#  'history.2025-03-26.listedDate',
#  'history.2025-03-26.removedDate',
#  'history.2025-03-26.daysOnMarket',
#  'history.2025-05-21.event',
#  'history.2025-05-21.price',
#  'history.2025-05-21.listingType',
#  'history.2025-05-21.listedDate',
#  'history.2025-05-21.removedDate',
#  'history.2025-05-21.daysOnMarket',
#  'history.2025-07-09.event',
#  'history.2025-07-09.price',
#  'history.2025-07-09.listingType',
#  'history.2025-07-09.listedDate',
#  'history.2025-07-09.removedDate',
#  'history.2025-07-09.daysOnMarket',
#  'history.2024-08-07.event',
#  'history.2024-08-07.price',
#  'history.2024-08-07.listingType',
#  'history.2024-08-07.listedDate',
#  'history.2024-08-07.removedDate',
#  'history.2024-08-07.daysOnMarket',
#  'history.2025-02-01.event',
#  'history.2025-02-01.price',
#  'history.2025-02-01.listingType',
#  'history.2025-02-01.listedDate',
#  'history.2025-02-01.removedDate',
#  'history.2025-02-01.daysOnMarket',
#  'history.2025-04-30.event',
#  'history.2025-04-30.price',
#  'history.2025-04-30.listingType',
#  'history.2025-04-30.listedDate',
#  'history.2025-04-30.removedDate',
#  'history.2025-04-30.daysOnMarket',
#  'history.2025-03-28.event',
#  'history.2025-03-28.price',
#  'history.2025-03-28.listingType',
#  'history.2025-03-28.listedDate',
#  'history.2025-03-28.removedDate',
#  'history.2025-03-28.daysOnMarket',
#  'history.2025-03-06.event',
#  'history.2025-03-06.price',
#  'history.2025-03-06.listingType',
#  'history.2025-03-06.listedDate',
#  'history.2025-03-06.removedDate',
#  'history.2025-03-06.daysOnMarket',
#  'history.2025-04-22.event',
#  'history.2025-04-22.price',
#  'history.2025-04-22.listingType',
#  'history.2025-04-22.listedDate',
#  'history.2025-04-22.removedDate',
#  'history.2025-04-22.daysOnMarket',
#  'history.2024-09-05.event',
#  'history.2024-09-05.price',
#  'history.2024-09-05.listingType',
#  'history.2024-09-05.listedDate',
#  'history.2024-09-05.removedDate',
#  'history.2024-09-05.daysOnMarket',
#  'history.2025-05-30.event',
#  'history.2025-05-30.price',
#  'history.2025-05-30.listingType',
#  'history.2025-05-30.listedDate',
#  'history.2025-05-30.removedDate',
#  'history.2025-05-30.daysOnMarket',
#  'history.2025-02-04.event',
#  'history.2025-02-04.price',
#  'history.2025-02-04.listingType',
#  'history.2025-02-04.listedDate',
#  'history.2025-02-04.removedDate',
#  'history.2025-02-04.daysOnMarket',
#  'history.2024-12-12.event',
#  'history.2024-12-12.price',
#  'history.2024-12-12.listingType',
#  'history.2024-12-12.listedDate',
#  'history.2024-12-12.removedDate',
#  'history.2024-12-12.daysOnMarket',
#  'history.2025-03-01.event',
#  'history.2025-03-01.price',
#  'history.2025-03-01.listingType',
#  'history.2025-03-01.listedDate',
#  'history.2025-03-01.removedDate',
#  'history.2025-03-01.daysOnMarket',
#  'history.2025-01-31.event',
#  'history.2025-01-31.price',
#  'history.2025-01-31.listingType',
#  'history.2025-01-31.listedDate',
#  'history.2025-01-31.removedDate',
#  'history.2025-01-31.daysOnMarket',
#  'history.2025-01-21.event',
#  'history.2025-01-21.price',
#  'history.2025-01-21.listingType',
#  'history.2025-01-21.listedDate',
#  'history.2025-01-21.removedDate',
#  'history.2025-01-21.daysOnMarket',
#  'history.2025-03-05.event',
#  'history.2025-03-05.price',
#  'history.2025-03-05.listingType',
#  'history.2025-03-05.listedDate',
#  'history.2025-03-05.removedDate',
#  'history.2025-03-05.daysOnMarket',
#  'history.2024-08-18.event',
#  'history.2024-08-18.price',
#  'history.2024-08-18.listingType',
#  'history.2024-08-18.listedDate',
#  'history.2024-08-18.removedDate',
#  'history.2024-08-18.daysOnMarket',
#  'history.2024-10-21.event',
#  'history.2024-10-21.price',
#  'history.2024-10-21.listingType',
#  'history.2024-10-21.listedDate',
#  'history.2024-10-21.removedDate',
#  'history.2024-10-21.daysOnMarket',
#  'history.2024-11-22.event',
#  'history.2024-11-22.price',
#  'history.2024-11-22.listingType',
#  'history.2024-11-22.listedDate',
#  'history.2024-11-22.removedDate',
#  'history.2024-11-22.daysOnMarket',
#  'history.2025-02-17.event',
#  'history.2025-02-17.price',
#  'history.2025-02-17.listingType',
#  'history.2025-02-17.listedDate',
#  'history.2025-02-17.removedDate',
#  'history.2025-02-17.daysOnMarket',
#  'history.2025-01-16.event',
#  'history.2025-01-16.price',
#  'history.2025-01-16.listingType',
#  'history.2025-01-16.listedDate',
#  'history.2025-01-16.removedDate',
#  'history.2025-01-16.daysOnMarket',
#  'history.2025-03-04.event',
#  'history.2025-03-04.price',
#  'history.2025-03-04.listingType',
#  'history.2025-03-04.listedDate',
#  'history.2025-03-04.removedDate',
#  'history.2025-03-04.daysOnMarket',
#  'history.2025-01-22.event',
#  'history.2025-01-22.price',
#  'history.2025-01-22.listingType',
#  'history.2025-01-22.listedDate',
#  'history.2025-01-22.removedDate',
#  'history.2025-01-22.daysOnMarket',
#  'history.2025-04-11.event',
#  'history.2025-04-11.price',
#  'history.2025-04-11.listingType',
#  'history.2025-04-11.listedDate',
#  'history.2025-04-11.removedDate',
#  'history.2025-04-11.daysOnMarket',
#  'history.2025-05-22.event',
#  'history.2025-05-22.price',
#  'history.2025-05-22.listingType',
#  'history.2025-05-22.listedDate',
#  'history.2025-05-22.removedDate',
#  'history.2025-05-22.daysOnMarket',
#  'history.2024-10-01.event',
#  'history.2024-10-01.price',
#  'history.2024-10-01.listingType',
#  'history.2024-10-01.listedDate',
#  'history.2024-10-01.removedDate',
#  'history.2024-10-01.daysOnMarket',
#  'history.2025-05-08.event',
#  'history.2025-05-08.price',
#  'history.2025-05-08.listingType',
#  'history.2025-05-08.listedDate',
#  'history.2025-05-08.removedDate',
#  'history.2025-05-08.daysOnMarket',
#  'history.2025-06-03.event',
#  'history.2025-06-03.price',
#  'history.2025-06-03.listingType',
#  'history.2025-06-03.listedDate',
#  'history.2025-06-03.removedDate',
#  'history.2025-06-03.daysOnMarket',
#  'history.2025-03-27.event',
#  'history.2025-03-27.price',
#  'history.2025-03-27.listingType',
#  'history.2025-03-27.listedDate',
#  'history.2025-03-27.removedDate',
#  'history.2025-03-27.daysOnMarket',
#  'history.2025-04-12.event',
#  'history.2025-04-12.price',
#  'history.2025-04-12.listingType',
#  'history.2025-04-12.listedDate',
#  'history.2025-04-12.removedDate',
#  'history.2025-04-12.daysOnMarket',
#  'history.2025-04-25.event',
#  'history.2025-04-25.price',
#  'history.2025-04-25.listingType',
#  'history.2025-04-25.listedDate',
#  'history.2025-04-25.removedDate',
#  'history.2025-04-25.daysOnMarket',
#  'history.2025-05-01.event',
#  'history.2025-05-01.price',
#  'history.2025-05-01.listingType',
#  'history.2025-05-01.listedDate',
#  'history.2025-05-01.removedDate',
#  'history.2025-05-01.daysOnMarket',
#  'history.2024-09-11.event',
#  'history.2024-09-11.price',
#  'history.2024-09-11.listingType',
#  'history.2024-09-11.listedDate',
#  'history.2024-09-11.removedDate',
#  'history.2024-09-11.daysOnMarket',
#  'history.2025-01-14.event',
#  'history.2025-01-14.price',
#  'history.2025-01-14.listingType',
#  'history.2025-01-14.listedDate',
#  'history.2025-01-14.removedDate',
#  'history.2025-01-14.daysOnMarket',
#  'history.2025-07-10.event',
#  'history.2025-07-10.price',
#  'history.2025-07-10.listingType',
#  'history.2025-07-10.listedDate',
#  'history.2025-07-10.removedDate',
#  'history.2025-07-10.daysOnMarket',
#  'history.2025-05-15.event',
#  'history.2025-05-15.price',
#  'history.2025-05-15.listingType',
#  'history.2025-05-15.listedDate',
#  'history.2025-05-15.removedDate',
#  'history.2025-05-15.daysOnMarket']

# %%
def transform_data(df):
    listing_data_cleaned = df[['id', 'formattedAddress', 'city',
       'state', 'zipCode', 'county', 'latitude', 'longitude', 'propertyType',
       'bedrooms', 'bathrooms', 'squareFootage', 'lotSize', 'yearBuilt',
       'status', 'price', 'listingType', 'listedDate', 'removedDate',
       'createdDate', 'lastSeenDate', 'daysOnMarket', 'mlsName', 'mlsNumber',
       'listingAgent.name', 'listingAgent.phone', 'listingAgent.email',
       'listingAgent.website', 'listingOffice.name', 'listingOffice.phone',
       'listingOffice.email', 'listingOffice.website']].copy()
    listing_data_cleaned.rename(columns={
        'formattedAddress': 'full_address','zipCode': 'postal_code'}, inplace=True
        )
    listing_data_cleaned.columns= (
        listing_data_cleaned.columns
        .str.strip()
        .str.replace(r'([A-Z])', r'_\1', regex=True)
        .str.replace(" ", "_")
        .str.replace(r'[^0-9a-zA-Z_]', r'_', regex=True)
        .str.lower()
        .str.replace('__', '_')
        .str.strip('_')
        )
    return listing_data_cleaned

# %%
listing_data_cleaned = transform_data(df)

# %% [markdown]
# TRANSFORMED DATA TO BE LOADED INTO THE DATABASE

# %%
engine = create_engine(f"postgresql+psycopg2://{user_name}:{password}@{host}:{port}/{db_name}")

# %%
listing_data_cleaned.to_sql('transformed_listings', con=engine, if_exists='replace', index=False, method="multi")
# Out:
# 150

# %%
cur=conn.cursor()

# %%
conn.commit()

# %%
def main() -> int:
    logging.info("ETL start")
    try:
        df = extract_data(url)
        df.to_sql("raw_listings", engine, if_exists="replace", index=False,method="multi")

        df_list_clean = transform_data(df)
        df_list_clean.to_sql("transformed_listings", engine, if_exists="replace", index=False,method="multi")

        logging.info("Rows: raw=%s clean=%s", len(df), len(df_list_clean))
        logging.info("ETL success")
        return 0
    except Exception:
        logging.error("ETL failed\n%s", traceback.format_exc())
        return 1

if __name__ == "__main__":
    main()
